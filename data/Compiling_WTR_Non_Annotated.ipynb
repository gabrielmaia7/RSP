# %%
import pandas as pd
import numpy as np
from ast import literal_eval as leval
import seaborn as sns
from tqdm.auto import tqdm
tqdm.pandas()
from matplotlib import pyplot as plt

# %%
reference_text_df = pd.read_csv('text_extraction/reference_html_as_sentences_df.csv')

claim_data_df = pd.read_csv('text_extraction/text_reference_claims_df.csv')

# %%
reference_text_df.info()
reference_text_df_trim = reference_text_df.drop(
    ['error_msg','code','content-type','reason','language_crawl','language_crawl_score',
    'sampling_weight_vb', 'sampling_weight', 'extracted_sentences', 'extracted_text', 'nlp_sentences',
    'nlp_sentences_slide_2'], axis=1
)
reference_text_df_trim.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 676 entries, 0 to 675
# Data columns (total 20 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   reference_id           676 non-null    object
#  1   reference_property_id  676 non-null    object
#  2   reference_datatype     676 non-null    object
#  3   url                    676 non-null    object
#  4   netloc                 676 non-null    object
#  5   netloc_agg             676 non-null    object
#  6   error_msg              676 non-null    object
#  7   code                   676 non-null    int64
#  8   content-type           676 non-null    object
#  9   final_url              676 non-null    object
#  10  reason                 662 non-null    object
#  11  language_crawl         676 non-null    object
#  12  language_crawl_score   676 non-null    float64
#  13  sampling_weight_vb     676 non-null    object
#  14  sampling_weight        676 non-null    float64
#  15  html                   676 non-null    object
#  16  extracted_sentences    676 non-null    object
#  17  extracted_text         676 non-null    object
#  18  nlp_sentences          676 non-null    object
#  19  nlp_sentences_slide_2  676 non-null    object
# dtypes: float64(2), int64(1), object(17)
# memory usage: 105.8+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 676 entries, 0 to 675
# Data columns (total 8 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   reference_id           676 non-null    object
#  1   reference_property_id  676 non-null    object
#  2   reference_datatype     676 non-null    object
#  3   url                    676 non-null    object
#  4   netloc                 676 non-null    object
#  5   netloc_agg             676 non-null    object
#  6   final_url              676 non-null    object
#  7   html                   676 non-null    object
# dtypes: object(8)
# memory usage: 42.4+ KB

# %%
# Correct some final_urls in the reference_text_df dataframe before joining
import re

# Replace by archived page if page was behing paywall when parsed
reference_text_df_trim.loc[reference_text_df_trim.html.map(lambda x : '://archive.ph/' in x), 'final_url'] =\
    reference_text_df_trim.loc[reference_text_df_trim.html.map(lambda x : '://archive.ph/' in x)]\
        .html.map(lambda x : re.findall(r'http(?:s){0,1}://archive.ph/(?:[a-zA-Z0-9]*)', x)[0])

# %%
claim_data_df.info()
claim_data_df_trim = claim_data_df[
    [
        'reference_id','claim_id','rank','datatype','datavalue',
        'entity_id','property_id',
        'entity_label','property_label','object_label',
        'entity_alias','property_alias','object_alias',
        'entity_desc','property_desc','object_desc'
    ]
].copy()

claim_data_df_trim['verb_mock'] = claim_data_df_trim.apply(
    lambda row: '$'.join([row['entity_label'], row['property_label'], row['object_label']]), axis=1
)

claim_data_df_trim.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1572 entries, 0 to 1571
# Data columns (total 25 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   reference_id        1572 non-null   object
#  1   entity_id           1572 non-null   object
#  2   claim_id            1572 non-null   object
#  3   rank                1572 non-null   object
#  4   property_id         1572 non-null   object
#  5   datatype            1572 non-null   object
#  6   datavalue           1572 non-null   object
#  7   entity_label        1572 non-null   object
#  8   entity_label_lan    1572 non-null   object
#  9   property_label      1572 non-null   object
#  10  property_label_lan  1572 non-null   object
#  11  entity_alias        1572 non-null   object
#  12  entity_alias_lan    1572 non-null   object
#  13  property_alias      1572 non-null   object
#  14  property_alias_lan  1572 non-null   object
#  15  entity_desc         1572 non-null   object
#  16  entity_desc_lan     1572 non-null   object
#  17  property_desc       1572 non-null   object
#  18  property_desc_lan   1572 non-null   object
#  19  object_label        1572 non-null   object
#  20  object_label_lan    1572 non-null   object
#  21  object_alias        1572 non-null   object
#  22  object_alias_lan    1572 non-null   object
#  23  object_desc         1572 non-null   object
#  24  object_desc_lan     1572 non-null   object
# dtypes: object(25)
# memory usage: 307.2+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1572 entries, 0 to 1571
# Data columns (total 17 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   reference_id    1572 non-null   object
#  1   claim_id        1572 non-null   object
#  2   rank            1572 non-null   object
#  3   datatype        1572 non-null   object
#  4   datavalue       1572 non-null   object
#  5   entity_id       1572 non-null   object
#  6   property_id     1572 non-null   object
#  7   entity_label    1572 non-null   object
#  8   property_label  1572 non-null   object
#  9   object_label    1572 non-null   object
#  10  entity_alias    1572 non-null   object
#  11  property_alias  1572 non-null   object
#  12  object_alias    1572 non-null   object
#  13  entity_desc     1572 non-null   object
#  14  property_desc   1572 non-null   object
#  15  object_desc     1572 non-null   object
#  16  verb_mock       1572 non-null   object
# dtypes: object(17)
# memory usage: 208.9+ KB

# %%
# REMOVE P1448 (OFFICIAL NAME), P1476 (TITLE), AND P1889 (DIFFERENT) AS THEY ARE REDUNDANT AND NON-INFORMATIVE
#also look at the dataset creation for other properties that were deleted and delete them too

BAD_PROPERTIES = [
    'P1448', # offical name
    'P1476', # title
    'P1889',# different
    'P31', # - instance of
    'P279',# - subclass of
    'P373',# - commons category
    'P910',# - Topic's main category
    'P7561',# - category for the interior of the item
    'P5008',# - on focus list of Wikimedia project
    'P2670',# -  has parts of the class
    'P1740',# -  category for films shot at this location
    'P1612',# -  Commons Institution page
    'P8989',# -  category for the view of the item
    'P2959',# -  permanent duplicated item
    'P7867',# -  category for maps
    'P935' ,# -  Commons gallery
    'P1472',#  -  Commons Creator page
    'P8596',# category for the exterior of the item
    'P5105',# Deutsche Bahn station category
    'P8933',# category for the view from the item
    'P642',# of
    'P3876',# category for alumni of educational institution
    'P1791',# category of people buried here
    'P7084',# related category
    'P1465',# category for people who died here
    'P1687',# Wikidata property
    'P6104',# maintained by WikiProject
    'P4195',# category for employees of the organization
    'P1792',# category of associated people
    'P5869',# model item
    'P1659',# see also
    'P1464',# category for people born here
    'P2354',# has list
    'P1424',# topic's main template
    'P7782',# category for ship name
    'P179',# part of the series
    'P7888',# merged into
    'P6365',# member category
    'P8464',# content partnership category
    'P360',# is a list of
    'P805',# statement is subject of
    'P8703',# entry in abbreviations table
    'P1456',# list of monuments
    'P1012',# including
    'P1151',# topic's main Wikimedia portal
    'P2490',# page at OSTIS Belarus Wiki
    'P593',# HomoloGene ID
    'P8744',# economy of topic
    'P2614',# World Heritage criteria
    'P2184',# history of topic
    'P9241',# demographics of topic
    'P487',#Unicode character
    'P1754',#category related to list
    'P2559',#Wikidata usage instructions
    'P2517',#category for recipients of this award
    'P971',#category combines topics
    'P6112',# category for members of a team
    'P4224',#category contains
    'P301',#category's main topic
    'P1753',#list related to category
    'P1423',#template has topic
    'P1204',#Wikimedia portal's main topic
    'P3921',#Wikidata SPARQL query equivalent
    'P1963',#properties for this type
    'P5125',#Wikimedia outline
    'P3176',#uses property
    'P8952',#inappropriate property for this type
    'P2306',#property
    'P5193',#Wikidata property example for forms
    'P5977',#Wikidata property example for senses
    'P1748',#NCI Thesaurus ID
    'P1692',#ICD-9-CM
    'P248',#stated in
]

claim_data_df_trim = claim_data_df_trim.drop(473, axis='index') #No english object label or aliases
claim_data_df_trim = claim_data_df_trim.drop(593, axis='index') #No english object label or aliases
claim_data_df_trim = claim_data_df_trim.reset_index(drop=True)

claim_data_df_trim_badpropdrop = claim_data_df_trim[
    ~claim_data_df_trim['property_id'].isin(BAD_PROPERTIES)
]
print('Percentage [Number] of claims dropped due to bad properties')
print(
    f'{100 - 100*claim_data_df_trim_badpropdrop.shape[0]/claim_data_df_trim.shape[0]}',
    f'[{claim_data_df_trim.shape[0] - claim_data_df_trim_badpropdrop.shape[0]}]'
)
# Out:
# Percentage [Number] of claims dropped due to bad properties
# 15.031847133757964 [236]

# %%
# Get URLs from the references df
wtr = pd.merge(
    reference_text_df_trim,
    claim_data_df_trim_badpropdrop,
    on='reference_id'
)
wtr
# Out:
#                                   reference_id reference_property_id  \
# 0     390d6c6e68a32e11f8d7b0883cda0557db529fe6                 P4656
# 1     49b9aec8e10815611ff0379a34d5fd7c3830566e                 P4656
# 2     ab3e9ada7246257ffbfb86fa90a54f25e45a704e                 P4656
# 3     ab3e9ada7246257ffbfb86fa90a54f25e45a704e                 P4656
# 4     76b04346ad57869d9e5ae1007ba8343d708ab6f9                 P4656
# ...                                        ...                   ...
# 1329  c714ca621d1fe1ca35f20e01a72587d23bdd8e1e                  P854
# 1330  52968f905e88f2484e3cb43e6ab4e76f120bc3c3                  P854
# 1331  8bb93e520f7ca8208f24078434b8f5f2ba8b520b                  P854
# 1332  8bb93e520f7ca8208f24078434b8f5f2ba8b520b                  P854
# 1333  6e6204011de4f4176362a6f4067486a94fc6ac3e                  P854
#
#      reference_datatype                                                url  \
# 0                   url  https://en.wikipedia.org/w/index.php?title=G._...
# 1                   url  https://en.wikipedia.org/w/index.php?title=Seb...
# 2                   url  https://en.wikipedia.org/w/index.php?title=Ave...
# 3                   url  https://en.wikipedia.org/w/index.php?title=Ave...
# 4                   url  https://en.wikipedia.org/w/index.php?title=Yut...
# ...                 ...                                                ...
# 1329                url                          https://indiancine.ma/BTW
# 1330                url                          https://indiancine.ma/BTD
# 1331                url                          https://indiancine.ma/BKF
# 1332                url                          https://indiancine.ma/BKF
# 1333                url                           https://indiancine.ma/YI
#
#                 netloc        netloc_agg  \
# 0     en.wikipedia.org  en.wikipedia.org
# 1     en.wikipedia.org  en.wikipedia.org
# 2     en.wikipedia.org  en.wikipedia.org
# 3     en.wikipedia.org  en.wikipedia.org
# 4     en.wikipedia.org  en.wikipedia.org
# ...                ...               ...
# 1329     indiancine.ma     indiancine.ma
# 1330     indiancine.ma     indiancine.ma
# 1331     indiancine.ma     indiancine.ma
# 1332     indiancine.ma     indiancine.ma
# 1333     indiancine.ma     indiancine.ma
#
#                                               final_url  \
# 0     https://en.wikipedia.org/w/index.php?title=G._...
# 1     https://en.wikipedia.org/w/index.php?title=Seb...
# 2     https://en.wikipedia.org/w/index.php?title=Ave...
# 3     https://en.wikipedia.org/w/index.php?title=Ave...
# 4     https://en.wikipedia.org/w/index.php?title=Yut...
# ...                                                 ...
# 1329                          https://indiancine.ma/BTW
# 1330                          https://indiancine.ma/BTD
# 1331                          https://indiancine.ma/BKF
# 1332                          https://indiancine.ma/BKF
# 1333                           https://indiancine.ma/YI
#
#                                                    html  \
# 0     <html class="client-js ve-available" lang="en"...
# 1     <html class="client-js ve-available" lang="en"...
# 2     <html class="client-js ve-available" lang="en"...
# 3     <html class="client-js ve-available" lang="en"...
# 4     <html class="client-js ve-available" lang="en"...
# ...                                                 ...
# 1329  <html><head>\n        <meta charset="utf-8">\n...
# 1330  <html><head>\n        <meta charset="utf-8">\n...
# 1331  <html><head>\n        <meta charset="utf-8">\n...
# 1332  <html><head>\n        <meta charset="utf-8">\n...
# 1333  <html><head>\n        <meta charset="utf-8">\n...
#
#                                             claim_id    rank  ...  \
# 0      Q5512528$81E8AD02-28AF-4AE3-8ACD-047C30B40B01  normal  ...
# 1     Q12149940$C9FE5F0C-78FD-4ECE-B1C2-16A763B8ED4E  normal  ...
# 2       Q583556$929DCD2F-3B4A-41B5-89E7-EEC549077834  normal  ...
# 3       Q583556$2AD75C92-953E-47CB-93A6-D082674F4231  normal  ...
# 4      Q7586053$AD344012-A522-4A8A-AF64-16F859E2EA9A  normal  ...
# ...                                              ...     ...  ...
# 1329  Q58485125$0B087946-63A0-4D69-BAEA-AD52DFBE2C6F  normal  ...
# 1330  Q58485081$AF144153-1EF3-4494-BBCC-90742E594482  normal  ...
# 1331  Q58484448$9611AF89-1BD2-4D49-9CBB-E3EC52C7765D  normal  ...
# 1332  Q58484448$E03C8ED8-0593-4D47-B002-6371900A238E  normal  ...
# 1333  Q58435606$82576BDF-9365-462C-B1F8-A6FF6B8FBE9D  normal  ...
#
#             entity_label                        property_label  \
# 0             G. V. Raja                        place of death
# 1        Sebastian Sabol                              religion
# 2     Average White Band                 location of formation
# 3     Average White Band                   work period (start)
# 4         Yutaka Higuchi                   work period (start)
# ...                  ...                                   ...
# 1329           Navjeevan  original language of film or TV show
# 1330       Mantra Shakti  original language of film or TV show
# 1331         Gul Sanobar  original language of film or TV show
# 1332         Gul Sanobar                                 color
# 1333         Jai Bhawani                                 color
#
#                object_label                 entity_alias  \
# 0              Kullu Valley  ['G.V. Raja', 'ജി.വി. രാജ']
# 1     Greek catholic church   ['Sebastian Stepan Sabol']
# 2                    Dundee       ['Average White Band']
# 3                      1972       ['Average White Band']
# 4                      1983             ['Ютака Хигути']
# ...                     ...                          ...
# 1329                  Hindi                     no-alias
# 1330                Bengali                     no-alias
# 1331                  Hindi                     no-alias
# 1332        black and white                     no-alias
# 1333        black and white                     no-alias
#
#                                          property_alias  \
# 0     ['deathplace', 'died in', 'death place', 'POD'...
# 1     ['religious affiliation', 'faith', 'life stanc...
# 2     ['originates from', 'comes from', 'place of fo...
# 3     ['floruit (start)', 'floruit start', 'flourish...
# 4     ['floruit (start)', 'floruit start', 'flourish...
# ...                                                 ...
# 1329  ['original language', 'language of the origina...
# 1330  ['original language', 'language of the origina...
# 1331  ['original language', 'language of the origina...
# 1332  ['colour', 'colors', 'colours', 'has color', '...
# 1333  ['colour', 'colors', 'colours', 'has color', '...
#
#                                            object_alias  \
# 0          ['Kulû', 'Vallee de Kulu', 'Vallée de kulu']
# 1     ['Iglesia Católica Griega', 'Iglesia catolica ...
# 2                                    ['City of Dundee']
# 3                                              no-alias
# 4                                              no-alias
# ...                                                 ...
# 1329  ['Hindi language', 'Modern Standard Hindi', 'hi']
# 1330        ['Bengali language', 'Bangla', 'bn', 'ben']
# 1331  ['Hindi language', 'Modern Standard Hindi', 'hi']
# 1332  ['B/W', 'B&W', 'colorless cinema', 'black-and-...
# 1333  ['B/W', 'B&W', 'colorless cinema', 'black-and-...
#
#                                             entity_desc  \
# 0                                       sports official
# 1     Ukrainian Basilian priest, poet and writer (19...
# 2                                     Scottish R&B band
# 3                                     Scottish R&B band
# 4                                     Japanese musician
# ...                                                 ...
# 1329                                          1935 film
# 1330                                          1935 film
# 1331                                          1934 film
# 1332                                          1934 film
# 1333                                          1928 film
#
#                                           property_desc  \
# 0     most specific known (e.g. city instead of coun...
# 1     religion of a person, organization or religiou...
# 2     location where a group or organization was formed
# 3     start of period during which a person or group...
# 4     start of period during which a person or group...
# ...                                                 ...
# 1329  language in which a film or a performance work...
# 1330  language in which a film or a performance work...
# 1331  language in which a film or a performance work...
# 1332                                   color of subject
# 1333                                   color of subject
#
#                                             object_desc  \
# 0                     valley in Himachal Pradesh, India
# 1     group of Eastern Catholic Churches following t...
# 2                                      city in Scotland
# 3                                               no-desc
# 4                                               no-desc
# ...                                                 ...
# 1329                                Indo-Aryan language
# 1330  Indo-Aryan language mainly spoken in Banglades...
# 1331                                Indo-Aryan language
# 1332                     monochrome form in visual arts
# 1333                     monochrome form in visual arts
#
#                                               verb_mock
# 0                G. V. Raja$place of death$Kullu Valley
# 1        Sebastian Sabol$religion$Greek catholic church
# 2       Average White Band$location of formation$Dundee
# 3           Average White Band$work period (start)$1972
# 4               Yutaka Higuchi$work period (start)$1983
# ...                                                 ...
# 1329  Navjeevan$original language of film or TV show...
# 1330  Mantra Shakti$original language of film or TV ...
# 1331  Gul Sanobar$original language of film or TV sh...
# 1332                  Gul Sanobar$color$black and white
# 1333                  Jai Bhawani$color$black and white
#
# [1334 rows x 24 columns]

# %%
wtr.reference_id.unique().shape
# Out:
# (651,)

# %%
# Remove duplicates of reference and verbalisation, as duplicates arise from qualifier dependancy
wtr_duplidrop = \
    wtr.drop_duplicates(
    ['verb_mock','final_url'], keep='first'
)

wtr_duplidrop = wtr_duplidrop.drop(806, axis='index') #Verb will be equal

print('Percentage [Number] of claims dropped due to duplicated verbalisation and url pair')
print(
    f'{100 - 100*wtr_duplidrop.shape[0]/wtr.shape[0]}',
    f'[{wtr.shape[0] - wtr_duplidrop.shape[0]}]'
)
# Out:
# Percentage [Number] of claims dropped due to duplicated verbalisation and url pair
# 2.0989505247376314 [28]

# %%
# Remove the three cases in archinform.net written in German
wtr_duplidrop = wtr_duplidrop[
    ~wtr_duplidrop['final_url'].map(
        lambda x : 'www.archinform.net' in x and any([(y in x) for y in ['19632','11996','45859']])
    )
]

# %%
wtr_duplidrop = wtr_duplidrop.reset_index(drop=True)

# %%
wtr_duplidrop
# Out:
#                                   reference_id reference_property_id  \
# 0     390d6c6e68a32e11f8d7b0883cda0557db529fe6                 P4656
# 1     49b9aec8e10815611ff0379a34d5fd7c3830566e                 P4656
# 2     ab3e9ada7246257ffbfb86fa90a54f25e45a704e                 P4656
# 3     ab3e9ada7246257ffbfb86fa90a54f25e45a704e                 P4656
# 4     76b04346ad57869d9e5ae1007ba8343d708ab6f9                 P4656
# ...                                        ...                   ...
# 1297  c714ca621d1fe1ca35f20e01a72587d23bdd8e1e                  P854
# 1298  52968f905e88f2484e3cb43e6ab4e76f120bc3c3                  P854
# 1299  8bb93e520f7ca8208f24078434b8f5f2ba8b520b                  P854
# 1300  8bb93e520f7ca8208f24078434b8f5f2ba8b520b                  P854
# 1301  6e6204011de4f4176362a6f4067486a94fc6ac3e                  P854
#
#      reference_datatype                                                url  \
# 0                   url  https://en.wikipedia.org/w/index.php?title=G._...
# 1                   url  https://en.wikipedia.org/w/index.php?title=Seb...
# 2                   url  https://en.wikipedia.org/w/index.php?title=Ave...
# 3                   url  https://en.wikipedia.org/w/index.php?title=Ave...
# 4                   url  https://en.wikipedia.org/w/index.php?title=Yut...
# ...                 ...                                                ...
# 1297                url                          https://indiancine.ma/BTW
# 1298                url                          https://indiancine.ma/BTD
# 1299                url                          https://indiancine.ma/BKF
# 1300                url                          https://indiancine.ma/BKF
# 1301                url                           https://indiancine.ma/YI
#
#                 netloc        netloc_agg  \
# 0     en.wikipedia.org  en.wikipedia.org
# 1     en.wikipedia.org  en.wikipedia.org
# 2     en.wikipedia.org  en.wikipedia.org
# 3     en.wikipedia.org  en.wikipedia.org
# 4     en.wikipedia.org  en.wikipedia.org
# ...                ...               ...
# 1297     indiancine.ma     indiancine.ma
# 1298     indiancine.ma     indiancine.ma
# 1299     indiancine.ma     indiancine.ma
# 1300     indiancine.ma     indiancine.ma
# 1301     indiancine.ma     indiancine.ma
#
#                                               final_url  \
# 0     https://en.wikipedia.org/w/index.php?title=G._...
# 1     https://en.wikipedia.org/w/index.php?title=Seb...
# 2     https://en.wikipedia.org/w/index.php?title=Ave...
# 3     https://en.wikipedia.org/w/index.php?title=Ave...
# 4     https://en.wikipedia.org/w/index.php?title=Yut...
# ...                                                 ...
# 1297                          https://indiancine.ma/BTW
# 1298                          https://indiancine.ma/BTD
# 1299                          https://indiancine.ma/BKF
# 1300                          https://indiancine.ma/BKF
# 1301                           https://indiancine.ma/YI
#
#                                                    html  \
# 0     <html class="client-js ve-available" lang="en"...
# 1     <html class="client-js ve-available" lang="en"...
# 2     <html class="client-js ve-available" lang="en"...
# 3     <html class="client-js ve-available" lang="en"...
# 4     <html class="client-js ve-available" lang="en"...
# ...                                                 ...
# 1297  <html><head>\n        <meta charset="utf-8">\n...
# 1298  <html><head>\n        <meta charset="utf-8">\n...
# 1299  <html><head>\n        <meta charset="utf-8">\n...
# 1300  <html><head>\n        <meta charset="utf-8">\n...
# 1301  <html><head>\n        <meta charset="utf-8">\n...
#
#                                             claim_id    rank  ...  \
# 0      Q5512528$81E8AD02-28AF-4AE3-8ACD-047C30B40B01  normal  ...
# 1     Q12149940$C9FE5F0C-78FD-4ECE-B1C2-16A763B8ED4E  normal  ...
# 2       Q583556$929DCD2F-3B4A-41B5-89E7-EEC549077834  normal  ...
# 3       Q583556$2AD75C92-953E-47CB-93A6-D082674F4231  normal  ...
# 4      Q7586053$AD344012-A522-4A8A-AF64-16F859E2EA9A  normal  ...
# ...                                              ...     ...  ...
# 1297  Q58485125$0B087946-63A0-4D69-BAEA-AD52DFBE2C6F  normal  ...
# 1298  Q58485081$AF144153-1EF3-4494-BBCC-90742E594482  normal  ...
# 1299  Q58484448$9611AF89-1BD2-4D49-9CBB-E3EC52C7765D  normal  ...
# 1300  Q58484448$E03C8ED8-0593-4D47-B002-6371900A238E  normal  ...
# 1301  Q58435606$82576BDF-9365-462C-B1F8-A6FF6B8FBE9D  normal  ...
#
#             entity_label                        property_label  \
# 0             G. V. Raja                        place of death
# 1        Sebastian Sabol                              religion
# 2     Average White Band                 location of formation
# 3     Average White Band                   work period (start)
# 4         Yutaka Higuchi                   work period (start)
# ...                  ...                                   ...
# 1297           Navjeevan  original language of film or TV show
# 1298       Mantra Shakti  original language of film or TV show
# 1299         Gul Sanobar  original language of film or TV show
# 1300         Gul Sanobar                                 color
# 1301         Jai Bhawani                                 color
#
#                object_label                 entity_alias  \
# 0              Kullu Valley  ['G.V. Raja', 'ജി.വി. രാജ']
# 1     Greek catholic church   ['Sebastian Stepan Sabol']
# 2                    Dundee       ['Average White Band']
# 3                      1972       ['Average White Band']
# 4                      1983             ['Ютака Хигути']
# ...                     ...                          ...
# 1297                  Hindi                     no-alias
# 1298                Bengali                     no-alias
# 1299                  Hindi                     no-alias
# 1300        black and white                     no-alias
# 1301        black and white                     no-alias
#
#                                          property_alias  \
# 0     ['deathplace', 'died in', 'death place', 'POD'...
# 1     ['religious affiliation', 'faith', 'life stanc...
# 2     ['originates from', 'comes from', 'place of fo...
# 3     ['floruit (start)', 'floruit start', 'flourish...
# 4     ['floruit (start)', 'floruit start', 'flourish...
# ...                                                 ...
# 1297  ['original language', 'language of the origina...
# 1298  ['original language', 'language of the origina...
# 1299  ['original language', 'language of the origina...
# 1300  ['colour', 'colors', 'colours', 'has color', '...
# 1301  ['colour', 'colors', 'colours', 'has color', '...
#
#                                            object_alias  \
# 0          ['Kulû', 'Vallee de Kulu', 'Vallée de kulu']
# 1     ['Iglesia Católica Griega', 'Iglesia catolica ...
# 2                                    ['City of Dundee']
# 3                                              no-alias
# 4                                              no-alias
# ...                                                 ...
# 1297  ['Hindi language', 'Modern Standard Hindi', 'hi']
# 1298        ['Bengali language', 'Bangla', 'bn', 'ben']
# 1299  ['Hindi language', 'Modern Standard Hindi', 'hi']
# 1300  ['B/W', 'B&W', 'colorless cinema', 'black-and-...
# 1301  ['B/W', 'B&W', 'colorless cinema', 'black-and-...
#
#                                             entity_desc  \
# 0                                       sports official
# 1     Ukrainian Basilian priest, poet and writer (19...
# 2                                     Scottish R&B band
# 3                                     Scottish R&B band
# 4                                     Japanese musician
# ...                                                 ...
# 1297                                          1935 film
# 1298                                          1935 film
# 1299                                          1934 film
# 1300                                          1934 film
# 1301                                          1928 film
#
#                                           property_desc  \
# 0     most specific known (e.g. city instead of coun...
# 1     religion of a person, organization or religiou...
# 2     location where a group or organization was formed
# 3     start of period during which a person or group...
# 4     start of period during which a person or group...
# ...                                                 ...
# 1297  language in which a film or a performance work...
# 1298  language in which a film or a performance work...
# 1299  language in which a film or a performance work...
# 1300                                   color of subject
# 1301                                   color of subject
#
#                                             object_desc  \
# 0                     valley in Himachal Pradesh, India
# 1     group of Eastern Catholic Churches following t...
# 2                                      city in Scotland
# 3                                               no-desc
# 4                                               no-desc
# ...                                                 ...
# 1297                                Indo-Aryan language
# 1298  Indo-Aryan language mainly spoken in Banglades...
# 1299                                Indo-Aryan language
# 1300                     monochrome form in visual arts
# 1301                     monochrome form in visual arts
#
#                                               verb_mock
# 0                G. V. Raja$place of death$Kullu Valley
# 1        Sebastian Sabol$religion$Greek catholic church
# 2       Average White Band$location of formation$Dundee
# 3           Average White Band$work period (start)$1972
# 4               Yutaka Higuchi$work period (start)$1983
# ...                                                 ...
# 1297  Navjeevan$original language of film or TV show...
# 1298  Mantra Shakti$original language of film or TV ...
# 1299  Gul Sanobar$original language of film or TV sh...
# 1300                  Gul Sanobar$color$black and white
# 1301                  Jai Bhawani$color$black and white
#
# [1302 rows x 24 columns]

# %%
wtr_duplidrop.to_csv('WTR_non_filtered_non_annotated.csv', index=None)

# %%
wtr_trim = wtr_duplidrop.sample(frac=1, random_state=42).drop_duplicates('reference_id').sort_index().reset_index(drop=True)
wtr_trim.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 648 entries, 0 to 647
# Data columns (total 24 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   reference_id           648 non-null    object
#  1   reference_property_id  648 non-null    object
#  2   reference_datatype     648 non-null    object
#  3   url                    648 non-null    object
#  4   netloc                 648 non-null    object
#  5   netloc_agg             648 non-null    object
#  6   final_url              648 non-null    object
#  7   html                   648 non-null    object
#  8   claim_id               648 non-null    object
#  9   rank                   648 non-null    object
#  10  datatype               648 non-null    object
#  11  datavalue              648 non-null    object
#  12  entity_id              648 non-null    object
#  13  property_id            648 non-null    object
#  14  entity_label           648 non-null    object
#  15  property_label         648 non-null    object
#  16  object_label           648 non-null    object
#  17  entity_alias           648 non-null    object
#  18  property_alias         648 non-null    object
#  19  object_alias           648 non-null    object
#  20  entity_desc            648 non-null    object
#  21  property_desc          648 non-null    object
#  22  object_desc            648 non-null    object
#  23  verb_mock              648 non-null    object
# dtypes: object(24)
# memory usage: 121.6+ KB

# %%
bad_netloc_aggs = [
    'witches.shca.ed.ac.uk', #Single infobox
    'en.isabart.org', #Single infobox
    'bechdeltest.com', #HAS API
    'npg.si.edu', #Image and single infobox
    'www.guidetopharmacology.org', #Single infobox
    'letterboxd.com', #Single infobox and has API
    'www.discogs.com', #Single infobox
    'vocab.getty.edu', #HAS JSON DUMPS
    'www.isfdb.org', #single infobox
    'www.npg.org.uk', #set of infoboxes
    'art.nationalgalleries.org', #image and single infobox
    'www.tate.org.uk', #image and single infobox
    'www.getty.edu', #HAS JSON DUMPS
    'memory-beta.fandom.com', #The portion with the information on Claims is just a long list of names and links
    'www.disease-ontology.org', #A single infobox
    'artgallery.yale.edu', #Image and a single infobox
    'www.imdb.com', #These are author pages and consist of a portrait, an infobox, and lists of movies
    'muckrack.com', #A very short infobox
    'live.dbpedia.org', #It's dbpedia, so it's mainly a huge infobox and there are dumps
    'dbpedia.org' #Same as above
]
wtr_trim_good = wtr_trim[~wtr_trim.netloc_agg.isin(bad_netloc_aggs)].reset_index(drop=True)

wtr_trim_good.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 409 entries, 0 to 408
# Data columns (total 24 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   reference_id           409 non-null    object
#  1   reference_property_id  409 non-null    object
#  2   reference_datatype     409 non-null    object
#  3   url                    409 non-null    object
#  4   netloc                 409 non-null    object
#  5   netloc_agg             409 non-null    object
#  6   final_url              409 non-null    object
#  7   html                   409 non-null    object
#  8   claim_id               409 non-null    object
#  9   rank                   409 non-null    object
#  10  datatype               409 non-null    object
#  11  datavalue              409 non-null    object
#  12  entity_id              409 non-null    object
#  13  property_id            409 non-null    object
#  14  entity_label           409 non-null    object
#  15  property_label         409 non-null    object
#  16  object_label           409 non-null    object
#  17  entity_alias           409 non-null    object
#  18  property_alias         409 non-null    object
#  19  object_alias           409 non-null    object
#  20  entity_desc            409 non-null    object
#  21  property_desc          409 non-null    object
#  22  object_desc            409 non-null    object
#  23  verb_mock              409 non-null    object
# dtypes: object(24)
# memory usage: 76.8+ KB

# %%
wtr_trim_good
# Out:
#                                  reference_id reference_property_id  \
# 0    390d6c6e68a32e11f8d7b0883cda0557db529fe6                 P4656
# 1    49b9aec8e10815611ff0379a34d5fd7c3830566e                 P4656
# 2    ab3e9ada7246257ffbfb86fa90a54f25e45a704e                 P4656
# 3    76b04346ad57869d9e5ae1007ba8343d708ab6f9                 P4656
# 4    1ee71b39caf6df395c64b436fea4895692812d38                 P4656
# ..                                        ...                   ...
# 404  e004706cba4821386dc31a86faeb680e8fff4ae7                  P854
# 405  c714ca621d1fe1ca35f20e01a72587d23bdd8e1e                  P854
# 406  52968f905e88f2484e3cb43e6ab4e76f120bc3c3                  P854
# 407  8bb93e520f7ca8208f24078434b8f5f2ba8b520b                  P854
# 408  6e6204011de4f4176362a6f4067486a94fc6ac3e                  P854
#
#     reference_datatype                                                url  \
# 0                  url  https://en.wikipedia.org/w/index.php?title=G._...
# 1                  url  https://en.wikipedia.org/w/index.php?title=Seb...
# 2                  url  https://en.wikipedia.org/w/index.php?title=Ave...
# 3                  url  https://en.wikipedia.org/w/index.php?title=Yut...
# 4                  url  https://en.wikipedia.org/w/index.php?title=Dol...
# ..                 ...                                                ...
# 404                url                          https://indiancine.ma/ATB
# 405                url                          https://indiancine.ma/BTW
# 406                url                          https://indiancine.ma/BTD
# 407                url                          https://indiancine.ma/BKF
# 408                url                           https://indiancine.ma/YI
#
#                netloc        netloc_agg  \
# 0    en.wikipedia.org  en.wikipedia.org
# 1    en.wikipedia.org  en.wikipedia.org
# 2    en.wikipedia.org  en.wikipedia.org
# 3    en.wikipedia.org  en.wikipedia.org
# 4    en.wikipedia.org  en.wikipedia.org
# ..                ...               ...
# 404     indiancine.ma     indiancine.ma
# 405     indiancine.ma     indiancine.ma
# 406     indiancine.ma     indiancine.ma
# 407     indiancine.ma     indiancine.ma
# 408     indiancine.ma     indiancine.ma
#
#                                              final_url  \
# 0    https://en.wikipedia.org/w/index.php?title=G._...
# 1    https://en.wikipedia.org/w/index.php?title=Seb...
# 2    https://en.wikipedia.org/w/index.php?title=Ave...
# 3    https://en.wikipedia.org/w/index.php?title=Yut...
# 4    https://en.wikipedia.org/w/index.php?title=Dol...
# ..                                                 ...
# 404                          https://indiancine.ma/ATB
# 405                          https://indiancine.ma/BTW
# 406                          https://indiancine.ma/BTD
# 407                          https://indiancine.ma/BKF
# 408                           https://indiancine.ma/YI
#
#                                                   html  \
# 0    <html class="client-js ve-available" lang="en"...
# 1    <html class="client-js ve-available" lang="en"...
# 2    <html class="client-js ve-available" lang="en"...
# 3    <html class="client-js ve-available" lang="en"...
# 4    <html class="client-js ve-available" lang="en"...
# ..                                                 ...
# 404  <html><head>\n        <meta charset="utf-8">\n...
# 405  <html><head>\n        <meta charset="utf-8">\n...
# 406  <html><head>\n        <meta charset="utf-8">\n...
# 407  <html><head>\n        <meta charset="utf-8">\n...
# 408  <html><head>\n        <meta charset="utf-8">\n...
#
#                                            claim_id    rank  ...  \
# 0     Q5512528$81E8AD02-28AF-4AE3-8ACD-047C30B40B01  normal  ...
# 1    Q12149940$C9FE5F0C-78FD-4ECE-B1C2-16A763B8ED4E  normal  ...
# 2      Q583556$2AD75C92-953E-47CB-93A6-D082674F4231  normal  ...
# 3     Q7586053$AD344012-A522-4A8A-AF64-16F859E2EA9A  normal  ...
# 4     Q5289513$B0532490-8FEC-4744-9D74-61238B633898  normal  ...
# ..                                              ...     ...  ...
# 404  Q58480207$B8B66EE1-CD20-4426-846C-4B37DC5A55A4  normal  ...
# 405  Q58485125$0B087946-63A0-4D69-BAEA-AD52DFBE2C6F  normal  ...
# 406  Q58485081$AF144153-1EF3-4494-BBCC-90742E594482  normal  ...
# 407  Q58484448$9611AF89-1BD2-4D49-9CBB-E3EC52C7765D  normal  ...
# 408  Q58435606$82576BDF-9365-462C-B1F8-A6FF6B8FBE9D  normal  ...
#
#            entity_label                        property_label  \
# 0            G. V. Raja                        place of death
# 1       Sebastian Sabol                              religion
# 2    Average White Band                   work period (start)
# 3        Yutaka Higuchi                   work period (start)
# 4       Dolores Delirio                   work period (start)
# ..                  ...                                   ...
# 404         Laila Majnu                                 color
# 405           Navjeevan  original language of film or TV show
# 406       Mantra Shakti  original language of film or TV show
# 407         Gul Sanobar  original language of film or TV show
# 408         Jai Bhawani                                 color
#
#               object_label                 entity_alias  \
# 0             Kullu Valley  ['G.V. Raja', 'ജി.വി. രാജ']
# 1    Greek catholic church   ['Sebastian Stepan Sabol']
# 2                     1972       ['Average White Band']
# 3                     1983             ['Ютака Хигути']
# 4                     1994                     no-alias
# ..                     ...                          ...
# 404        black and white                     no-alias
# 405                  Hindi                     no-alias
# 406                Bengali                     no-alias
# 407                  Hindi                     no-alias
# 408        black and white                     no-alias
#
#                                         property_alias  \
# 0    ['deathplace', 'died in', 'death place', 'POD'...
# 1    ['religious affiliation', 'faith', 'life stanc...
# 2    ['floruit (start)', 'floruit start', 'flourish...
# 3    ['floruit (start)', 'floruit start', 'flourish...
# 4    ['floruit (start)', 'floruit start', 'flourish...
# ..                                                 ...
# 404  ['colour', 'colors', 'colours', 'has color', '...
# 405  ['original language', 'language of the origina...
# 406  ['original language', 'language of the origina...
# 407  ['original language', 'language of the origina...
# 408  ['colour', 'colors', 'colours', 'has color', '...
#
#                                           object_alias  \
# 0         ['Kulû', 'Vallee de Kulu', 'Vallée de kulu']
# 1    ['Iglesia Católica Griega', 'Iglesia catolica ...
# 2                                             no-alias
# 3                                             no-alias
# 4                                             no-alias
# ..                                                 ...
# 404  ['B/W', 'B&W', 'colorless cinema', 'black-and-...
# 405  ['Hindi language', 'Modern Standard Hindi', 'hi']
# 406        ['Bengali language', 'Bangla', 'bn', 'ben']
# 407  ['Hindi language', 'Modern Standard Hindi', 'hi']
# 408  ['B/W', 'B&W', 'colorless cinema', 'black-and-...
#
#                                            entity_desc  \
# 0                                      sports official
# 1    Ukrainian Basilian priest, poet and writer (19...
# 2                                    Scottish R&B band
# 3                                    Japanese musician
# 4                                grupo musical peruano
# ..                                                 ...
# 404                           1931 film by J. J. Madan
# 405                                          1935 film
# 406                                          1935 film
# 407                                          1934 film
# 408                                          1928 film
#
#                                          property_desc  \
# 0    most specific known (e.g. city instead of coun...
# 1    religion of a person, organization or religiou...
# 2    start of period during which a person or group...
# 3    start of period during which a person or group...
# 4    start of period during which a person or group...
# ..                                                 ...
# 404                                   color of subject
# 405  language in which a film or a performance work...
# 406  language in which a film or a performance work...
# 407  language in which a film or a performance work...
# 408                                   color of subject
#
#                                            object_desc  \
# 0                    valley in Himachal Pradesh, India
# 1    group of Eastern Catholic Churches following t...
# 2                                              no-desc
# 3                                              no-desc
# 4                                              no-desc
# ..                                                 ...
# 404                     monochrome form in visual arts
# 405                                Indo-Aryan language
# 406  Indo-Aryan language mainly spoken in Banglades...
# 407                                Indo-Aryan language
# 408                     monochrome form in visual arts
#
#                                              verb_mock
# 0               G. V. Raja$place of death$Kullu Valley
# 1       Sebastian Sabol$religion$Greek catholic church
# 2          Average White Band$work period (start)$1972
# 3              Yutaka Higuchi$work period (start)$1983
# 4             Dolores Delirio$work period (start)$1994
# ..                                                 ...
# 404                  Laila Majnu$color$black and white
# 405  Navjeevan$original language of film or TV show...
# 406  Mantra Shakti$original language of film or TV ...
# 407  Gul Sanobar$original language of film or TV sh...
# 408                  Jai Bhawani$color$black and white
#
# [409 rows x 24 columns]
