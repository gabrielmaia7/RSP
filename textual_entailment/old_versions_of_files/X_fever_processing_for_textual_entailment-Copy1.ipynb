# %% [markdown]
# This notebook represents an alternative to generating labelled data for textual entailment.
# Differently from `0_fever_decode_wikipage_IDs_to_sentences`, this one takes the FEVER data directly from the processed data from the kgat team.
#
# This is better for one main reason: where the other notebook created *a single completely random sentence* for the NOT ENOUGH INFO cases, this one is able to draw from pre-selected sentences that, *while related to the claim, do not support nor refute it*.
#
# This is very important, as the former approach meant the data was very easy to perform well in, as the sentences were simply completely unrelated, and much clearer to define as "not argumentative" to the claim.

# %%
import json
import pandas as pd
import random
import numpy as np
import sqlite3 as sql

# %%
all_df = []
with open('kgat_proc_data/bert_train.json','r') as f:
    for line in f:
        row = json.loads(line)
        all_df.append(row)
all_df = pd.DataFrame(all_df)
all_df
# Out:
#             id                                           evidence  \
# 0        75397  [[Fox_Broadcasting_Company, 0, The Fox Broadca...
# 1       150448  [[Roman_Atwood, 3, He also has another YouTube...
# 2       214861  [[History_of_art, 2, The subsequent expansion ...
# 3       156709  [[Adrienne_Bailon, 0, Adrienne Eliza Houghton ...
# 4        83235  [[System_of_a_Down, 6, The group briefly disba...
# ...        ...                                                ...
# 145444   75062  [[Led_Zeppelin_-LRB-album-RRB-, 0, Led Zeppeli...
# 145445  149256  [[Taal_-LRB-film-RRB-, 0, Taal LRB English : R...
# 145446   13287  [[Rooney_Mara, 0, Patricia Rooney Mara LRB LSB...
# 145447   13114  [[Gimli_-LRB-Middle-earth-RRB-, 1, A dwarf war...
# 145448  152180  [[Susan_Sarandon, 1, She is an Academy Award a...
#
#                                                     claim            label
# 0       Nikolaj Coster-Waldau worked with the Fox Broa...         SUPPORTS
# 1                      Roman Atwood is a content creator.         SUPPORTS
# 2       History of art includes architecture, dance, s...         SUPPORTS
# 3                       Adrienne Bailon is an accountant.          REFUTES
# 4            System of a Down briefly disbanded in limbo.  NOT ENOUGH INFO
# ...                                                   ...              ...
# 145444  Led Zeppelin released an eponymous debut album...          REFUTES
# 145445                                 Taal was romantic.         SUPPORTS
# 145446            Her stars American actress Rooney Mara.         SUPPORTS
# 145447                    J. R. R. Tolkien created Gimli.         SUPPORTS
# 145448                 Susan Sarandon is an award winner.         SUPPORTS
#
# [145449 rows x 4 columns]

# %%
gd_all_df = []
are_multihop = []
with open('kgat_proc_data/all_train.json','r') as f:
    for line in f:
        row = json.loads(line)
        row['golden_evidence'] = row.pop('evidence')
        row['golden_id'] = row.pop('id')
        row.pop('claim')
        row.pop('label')
        gd_all_df.append(row)
        if len([e for e in row['golden_evidence'] if e[3] == 2])>0:
            are_multihop.append(row['golden_id'])
gd_all_df = pd.DataFrame(gd_all_df)
gd_all_df
# Out:
#                                           golden_evidence  golden_id
# 0       [[Waldau, 0, Waldau may refer to :, 0], [Walda...      75397
# 1       [[Content_-LRB-media-RRB-, 0, In publishing , ...     150448
# 2       [[Architecture, 0, Architecture LRB Latin arch...     214861
# 3       [[Adrienne_Bailon, 0, Adrienne Eliza Houghton ...     156709
# 4       [[System_of_a_Down_-LRB-album-RRB-, 0, System ...      83235
# ...                                                   ...        ...
# 145444  [[1960, 0, It is also known as the `` Year of ...      75062
# 145445  [[Taal_-LRB-film-RRB-, 0, Taal LRB English : R...     149256
# 145446  [[Her, 0, Her is the objective form of the pro...      13287
# 145447  [[Gimli, 0, Gimli may refer to :, 0], [Gimli, ...      13114
# 145448  [[Susan_Sarandon, 0, Susan Abigail Sarandon LR...     152180
#
# [145449 rows x 2 columns]

# %%
all_df = pd.concat([all_df,gd_all_df],axis=1)
assert all(all_df['id'] == all_df['golden_id'])
all_df = all_df.drop('golden_id', axis=1)
all_df
# Out:
#             id                                           evidence  \
# 0        75397  [[Fox_Broadcasting_Company, 0, The Fox Broadca...
# 1       150448  [[Roman_Atwood, 3, He also has another YouTube...
# 2       214861  [[History_of_art, 2, The subsequent expansion ...
# 3       156709  [[Adrienne_Bailon, 0, Adrienne Eliza Houghton ...
# 4        83235  [[System_of_a_Down, 6, The group briefly disba...
# ...        ...                                                ...
# 145444   75062  [[Led_Zeppelin_-LRB-album-RRB-, 0, Led Zeppeli...
# 145445  149256  [[Taal_-LRB-film-RRB-, 0, Taal LRB English : R...
# 145446   13287  [[Rooney_Mara, 0, Patricia Rooney Mara LRB LSB...
# 145447   13114  [[Gimli_-LRB-Middle-earth-RRB-, 1, A dwarf war...
# 145448  152180  [[Susan_Sarandon, 1, She is an Academy Award a...
#
#                                                     claim            label  \
# 0       Nikolaj Coster-Waldau worked with the Fox Broa...         SUPPORTS
# 1                      Roman Atwood is a content creator.         SUPPORTS
# 2       History of art includes architecture, dance, s...         SUPPORTS
# 3                       Adrienne Bailon is an accountant.          REFUTES
# 4            System of a Down briefly disbanded in limbo.  NOT ENOUGH INFO
# ...                                                   ...              ...
# 145444  Led Zeppelin released an eponymous debut album...          REFUTES
# 145445                                 Taal was romantic.         SUPPORTS
# 145446            Her stars American actress Rooney Mara.         SUPPORTS
# 145447                    J. R. R. Tolkien created Gimli.         SUPPORTS
# 145448                 Susan Sarandon is an award winner.         SUPPORTS
#
#                                           golden_evidence
# 0       [[Waldau, 0, Waldau may refer to :, 0], [Walda...
# 1       [[Content_-LRB-media-RRB-, 0, In publishing , ...
# 2       [[Architecture, 0, Architecture LRB Latin arch...
# 3       [[Adrienne_Bailon, 0, Adrienne Eliza Houghton ...
# 4       [[System_of_a_Down_-LRB-album-RRB-, 0, System ...
# ...                                                   ...
# 145444  [[1960, 0, It is also known as the `` Year of ...
# 145445  [[Taal_-LRB-film-RRB-, 0, Taal LRB English : R...
# 145446  [[Her, 0, Her is the objective form of the pro...
# 145447  [[Gimli, 0, Gimli may refer to :, 0], [Gimli, ...
# 145448  [[Susan_Sarandon, 0, Susan Abigail Sarandon LR...
#
# [145449 rows x 5 columns]

# %%
all_df['label'].value_counts()
# Out:
# SUPPORTS           80035
# NOT ENOUGH INFO    35639
# REFUTES            29775
# Name: label, dtype: int64

# %%
# Only 14% of the evidence need multi-hop (train)
print(100*len(are_multihop)/all_df.shape[0])

# Filter out multihop
all_df = all_df[all_df.id.apply(lambda x : x not in are_multihop)].reset_index(drop=True)
all_df
# Out:
# 13.830964805533212
#             id                                           evidence  \
# 0       150448  [[Roman_Atwood, 3, He also has another YouTube...
# 1       214861  [[History_of_art, 2, The subsequent expansion ...
# 2       156709  [[Adrienne_Bailon, 0, Adrienne Eliza Houghton ...
# 3        83235  [[System_of_a_Down, 6, The group briefly disba...
# 4       149579  [[Beautiful_-LRB-Christina_Aguilera_song-RRB-,...
# ...        ...                                                ...
# 125327  225357  [[Absolute_Beginners_-LRB-film-RRB-, 1, The fi...
# 125328  116046  [[Neil_Young, 7, Young 's often distorted elec...
# 125329  149256  [[Taal_-LRB-film-RRB-, 0, Taal LRB English : R...
# 125330   13114  [[Gimli_-LRB-Middle-earth-RRB-, 1, A dwarf war...
# 125331  152180  [[Susan_Sarandon, 1, She is an Academy Award a...
#
#                                                     claim            label  \
# 0                      Roman Atwood is a content creator.         SUPPORTS
# 1       History of art includes architecture, dance, s...         SUPPORTS
# 2                       Adrienne Bailon is an accountant.          REFUTES
# 3            System of a Down briefly disbanded in limbo.  NOT ENOUGH INFO
# 4       Beautiful reached number two on the Billboard ...  NOT ENOUGH INFO
# ...                                                   ...              ...
# 125327            Absolute Beginners starred David Bowie.         SUPPORTS
# 125328             Neil Young is not a singer-songwriter.          REFUTES
# 125329                                 Taal was romantic.         SUPPORTS
# 125330                    J. R. R. Tolkien created Gimli.         SUPPORTS
# 125331                 Susan Sarandon is an award winner.         SUPPORTS
#
#                                           golden_evidence
# 0       [[Content_-LRB-media-RRB-, 0, In publishing , ...
# 1       [[Architecture, 0, Architecture LRB Latin arch...
# 2       [[Adrienne_Bailon, 0, Adrienne Eliza Houghton ...
# 3       [[System_of_a_Down_-LRB-album-RRB-, 0, System ...
# 4       [[Beautiful, 0, Beautiful , an adjective used ...
# ...                                                   ...
# 125327  [[Absolute_Beginners_-LRB-novel-RRB-, 0, Absol...
# 125328  [[Neil_Young_-LRB-disambiguation-RRB-, 0, Neil...
# 125329  [[Taal_-LRB-film-RRB-, 0, Taal LRB English : R...
# 125330  [[Gimli, 0, Gimli may refer to :, 0], [Gimli, ...
# 125331  [[Susan_Sarandon, 0, Susan Abigail Sarandon LR...
#
# [125332 rows x 5 columns]

# %%
''' 
To create the support detection dataset, the first strategy will be:
    For each SUPPORTS claim-evidence pair, we keep the pair if the evidence_score is 1 (is gold truth);
    For each REJECTS claim-evidence pair, we do the same as above;
    For each NOT ENOUGH INFO claim-evidence pair, we select N at random from the evidence pairs available
'''

def filter_for_support_detection(row):
    if row['label'] == 'NOT ENOUGH INFO':
        row_evidence = []
        for evidence in row['evidence']:
            keep = False
            if evidence[3] > 0.0:
                keep = True
            else:
                for gd_evidence in row['golden_evidence']:
                    if ((evidence[0],evidence[1]) == (gd_evidence[0],gd_evidence[1])) and gd_evidence[3] == 1:
                        print(row)
                        keep = True
            if keep:
                row_evidence.append(evidence)
        row['evidence'] = row_evidence
    else:
        row['evidence'] = [e for e in row['evidence'] if e[3] == 1]
    
    return(row)

all_df = all_df.apply(filter_for_support_detection, axis=1)

# %%
# Expand evidence into singular cases
all_df = all_df.drop('golden_evidence', axis=1)
expl_all_df = all_df.explode('evidence').reset_index(drop=True)
expl_all_df
# Out:
#             id                                           evidence  \
# 0       150448  [Roman_Atwood, 3, He also has another YouTube ...
# 1       150448  [Roman_Atwood, 1, He is best known for his vlo...
# 2       214861  [History_of_art, 2, The subsequent expansion o...
# 3       156709  [Adrienne_Bailon, 0, Adrienne Eliza Houghton L...
# 4        83235  [System_of_a_Down, 6, The group briefly disban...
# ...        ...                                                ...
# 179660   13114  [Gimli_-LRB-Middle-earth-RRB-, 1, A dwarf warr...
# 179661   13114  [Gimli_-LRB-Middle-earth-RRB-, 0, Gimli is a f...
# 179662  152180  [Susan_Sarandon, 1, She is an Academy Award an...
# 179663  152180  [Susan_Sarandon, 8, She has also won the BAFTA...
# 179664  152180  [Susan_Sarandon, 2, She was appointed a UNICEF...
#
#                                                     claim            label
# 0                      Roman Atwood is a content creator.         SUPPORTS
# 1                      Roman Atwood is a content creator.         SUPPORTS
# 2       History of art includes architecture, dance, s...         SUPPORTS
# 3                       Adrienne Bailon is an accountant.          REFUTES
# 4            System of a Down briefly disbanded in limbo.  NOT ENOUGH INFO
# ...                                                   ...              ...
# 179660                    J. R. R. Tolkien created Gimli.         SUPPORTS
# 179661                    J. R. R. Tolkien created Gimli.         SUPPORTS
# 179662                 Susan Sarandon is an award winner.         SUPPORTS
# 179663                 Susan Sarandon is an award winner.         SUPPORTS
# 179664                 Susan Sarandon is an award winner.         SUPPORTS
#
# [179665 rows x 4 columns]

# %%
# Some unverifiable claims do not have evidence recovered by the document retrieval

no_evidence = expl_all_df[expl_all_df['evidence'].apply(lambda x : type(x) != list)]
print(100*no_evidence.shape[0]/all_df['label'].value_counts()['NOT ENOUGH INFO'])

expl_all_df = expl_all_df[expl_all_df.evidence.apply(lambda x : type(x) == list)].reset_index(drop=True)
expl_all_df

# This reaches 10% if picking only those with sentence retrieval score > 0.0 OR with golden annotation = 1.
# It could that this is enough. If not, try picking at random for the "empty" NOT ENOUGH INFO cases
# Out:
# 16.00774432503718
#             id                                           evidence  \
# 0       150448  [Roman_Atwood, 3, He also has another YouTube ...
# 1       150448  [Roman_Atwood, 1, He is best known for his vlo...
# 2       214861  [History_of_art, 2, The subsequent expansion o...
# 3       156709  [Adrienne_Bailon, 0, Adrienne Eliza Houghton L...
# 4        83235  [System_of_a_Down, 6, The group briefly disban...
# ...        ...                                                ...
# 173955   13114  [Gimli_-LRB-Middle-earth-RRB-, 1, A dwarf warr...
# 173956   13114  [Gimli_-LRB-Middle-earth-RRB-, 0, Gimli is a f...
# 173957  152180  [Susan_Sarandon, 1, She is an Academy Award an...
# 173958  152180  [Susan_Sarandon, 8, She has also won the BAFTA...
# 173959  152180  [Susan_Sarandon, 2, She was appointed a UNICEF...
#
#                                                     claim            label
# 0                      Roman Atwood is a content creator.         SUPPORTS
# 1                      Roman Atwood is a content creator.         SUPPORTS
# 2       History of art includes architecture, dance, s...         SUPPORTS
# 3                       Adrienne Bailon is an accountant.          REFUTES
# 4            System of a Down briefly disbanded in limbo.  NOT ENOUGH INFO
# ...                                                   ...              ...
# 173955                    J. R. R. Tolkien created Gimli.         SUPPORTS
# 173956                    J. R. R. Tolkien created Gimli.         SUPPORTS
# 173957                 Susan Sarandon is an award winner.         SUPPORTS
# 173958                 Susan Sarandon is an award winner.         SUPPORTS
# 173959                 Susan Sarandon is an award winner.         SUPPORTS
#
# [173960 rows x 4 columns]

# %%
# Expanding the evidence row

expl_all_df[['evidence_page','evidence_line','evidence_text','evidence_score']] = pd.DataFrame(expl_all_df.evidence.tolist())
expl_all_df
# Out:
#             id                                           evidence  \
# 0       150448  [Roman_Atwood, 3, He also has another YouTube ...
# 1       150448  [Roman_Atwood, 1, He is best known for his vlo...
# 2       214861  [History_of_art, 2, The subsequent expansion o...
# 3       156709  [Adrienne_Bailon, 0, Adrienne Eliza Houghton L...
# 4        83235  [System_of_a_Down, 6, The group briefly disban...
# ...        ...                                                ...
# 173955   13114  [Gimli_-LRB-Middle-earth-RRB-, 1, A dwarf warr...
# 173956   13114  [Gimli_-LRB-Middle-earth-RRB-, 0, Gimli is a f...
# 173957  152180  [Susan_Sarandon, 1, She is an Academy Award an...
# 173958  152180  [Susan_Sarandon, 8, She has also won the BAFTA...
# 173959  152180  [Susan_Sarandon, 2, She was appointed a UNICEF...
#
#                                                     claim            label  \
# 0                      Roman Atwood is a content creator.         SUPPORTS
# 1                      Roman Atwood is a content creator.         SUPPORTS
# 2       History of art includes architecture, dance, s...         SUPPORTS
# 3                       Adrienne Bailon is an accountant.          REFUTES
# 4            System of a Down briefly disbanded in limbo.  NOT ENOUGH INFO
# ...                                                   ...              ...
# 173955                    J. R. R. Tolkien created Gimli.         SUPPORTS
# 173956                    J. R. R. Tolkien created Gimli.         SUPPORTS
# 173957                 Susan Sarandon is an award winner.         SUPPORTS
# 173958                 Susan Sarandon is an award winner.         SUPPORTS
# 173959                 Susan Sarandon is an award winner.         SUPPORTS
#
#                        evidence_page  evidence_line  \
# 0                       Roman_Atwood              3
# 1                       Roman_Atwood              1
# 2                     History_of_art              2
# 3                    Adrienne_Bailon              0
# 4                   System_of_a_Down              6
# ...                              ...            ...
# 173955  Gimli_-LRB-Middle-earth-RRB-              1
# 173956  Gimli_-LRB-Middle-earth-RRB-              0
# 173957                Susan_Sarandon              1
# 173958                Susan_Sarandon              8
# 173959                Susan_Sarandon              2
#
#                                             evidence_text  evidence_score
# 0       He also has another YouTube channel called `` ...        1.000000
# 1       He is best known for his vlogs , where he post...        1.000000
# 2       The subsequent expansion of the list of princi...        1.000000
# 3       Adrienne Eliza Houghton LRB née Bailon ; born ...        1.000000
# 4       The group briefly disbanded in August 2006 and...        0.999814
# ...                                                   ...             ...
# 173955  A dwarf warrior , he is the son of Glóin LRB a...        1.000000
# 173956  Gimli is a fictional character from J. R. R. T...        1.000000
# 173957  She is an Academy Award and BAFTA Award winner...        1.000000
# 173958  She has also won the BAFTA Award for Best Actr...        1.000000
# 173959  She was appointed a UNICEF Goodwill Ambassador...        1.000000
#
# [173960 rows x 8 columns]

# %%
expl_all_df.label.value_counts()

#NOT ENOUGH INFO    11117
#REFUTES             7438
#SUPPORTS            6839
#Name: label, dtype: int64
# Out:
# SUPPORTS           81583
# NOT ENOUGH INFO    59114
# REFUTES            33263
# Name: label, dtype: int64

# %%
expl_all_df.to_csv('support_train.csv', index=None)
